# %%
# LT 15/09/2022
# explore filtered context table by RMC

import hail as hl
hl.init(default_reference='GRCh38',
        spark_conf = {
            'spark.hadoop.fs.gs.requester.pays.mode': 'CUSTOM',
            'spark.hadoop.fs.gs.requester.pays.buckets': 'regional_missense_constraint',
            'spark.hadoop.fs.gs.requester.pays.project.id': 'constraint-232598',
        })
# Out:
# 2022-09-15 04:04:56 WARN  NativeCodeLoader:60 - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 2022-09-15 04:04:57 WARN  Utils:69 - Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Running on Apache Spark version 3.1.3
# SparkUI available at http://f2d5b27c1105:4041
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.98-f8833c1ae16b
# LOGGING: writing to /home/jupyter/hail-20220915-0404-0.2.98-f8833c1ae16b.log

# %%
# RMC filtered context
ht = hl.read_table('gs://regional_missense_constraint/resources/GRCh37/reference_data/ht/context_fasta_snps_only_vep_v1.ht')

# %%
ht.show()
# Out:
# +---------------+------------+---------+-----+-----+-------------------+
# | locus         | alleles    | context | ref | alt | methylation_level |
# +---------------+------------+---------+-----+-----+-------------------+
# | locus<GRCh37> | array<str> | str     | str | str |             int32 |
# +---------------+------------+---------+-----+-----+-------------------+
# | 1:69094       | ["G","A"]  | "ACC"   | "C" | "T" |                 0 |
# | 1:69094       | ["G","C"]  | "ACC"   | "C" | "G" |                 0 |
# | 1:69094       | ["G","T"]  | "ACC"   | "C" | "A" |                 0 |
# | 1:69095       | ["T","A"]  | "CAC"   | "A" | "T" |                 0 |
# | 1:69095       | ["T","C"]  | "CAC"   | "A" | "G" |                 0 |
# | 1:69095       | ["T","G"]  | "CAC"   | "A" | "C" |                 0 |
# | 1:69097       | ["A","C"]  | "GAC"   | "A" | "C" |                 0 |
# | 1:69097       | ["A","G"]  | "GAC"   | "A" | "G" |                 0 |
# ...

# %%
# look at ACTA1
ht.filter(ht.transcript=="ENST00000366684").show(50)
# Out:
# [Stage 12:===================================================>(2762 + 4) / 2796]
# +---------------+------------+---------+-----+-----+-------------------+
# | locus         | alleles    | context | ref | alt | methylation_level |
# +---------------+------------+---------+-----+-----+-------------------+
# | locus<GRCh37> | array<str> | str     | str | str |             int32 |
# +---------------+------------+---------+-----+-----+-------------------+
# | 1:229567249   | ["G","C"]  | "TCT"   | "C" | "G" |                 0 |
# | 1:229567249   | ["G","T"]  | "TCT"   | "C" | "A" |                 0 |
# | 1:229567250   | ["A","C"]  | "GAA"   | "A" | "C" |                 0 |
# | 1:229567250   | ["A","G"]  | "GAA"   | "A" | "G" |                 0 |
# | 1:229567250   | ["A","T"]  | "GAA"   | "A" | "T" |                 0 |
# | 1:229567251   | ["A","C"]  | "AAG"   | "A" | "C" |                 0 |
# | 1:229567251   | ["A","G"]  | "AAG"   | "A" | "G" |                 0 |
# ...

# %%
# look at ATP5F1B, which is on the positive strand
ht.filter(ht.transcript=="ENST00000366684").show(50)
